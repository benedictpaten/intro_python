# %% [markdown]
# # Lecture 1 - Intro (https://bit.ly/intro_python_01)
#
# Today:
#
# * Course basics (inc. Zybooks / Discord / Grading / Late Policy, etc.!)
# * Setting expectations about this course
# * What's a program?
# * Hello World!
# * Interpreted vs. compiled languages
# * Ways to run Python (notebooks, via the interactive console, via an editor (PyCharm))
# * Basic Input and Output
# * The debug loop
# * Comments
# * Basic types
#   * integers (ints)
#   * strings
#   * floating point numbers (floats)

# %% [markdown]
# # Basics
#
# * About lecturers:
#     * Benedict Paten, bpaten@ucsc.edu, PSB-405E
#     * Larissa A Munishkina, mlarissa@ucsc.edu (other section)
#     * Ishaan Anil Paranjape, iparanja@ucsc.edu (other section)
#     * Hao Yue, hyue11@ucsc.edu (other section)
#
# * Canvas:
#     * All the material is linked from Canvas
#
# * Online text book:
#     * How to think like a computer scientist (free!):
#       * http://www.openbookproject.net/thinkcs/python/english3e/
#
# * Other online resources (there are loads and loads of free resources on the internet), checkout:
#     * https://wiki.python.org/moin/BeginnersGuide/NonProgrammers

# %% [markdown]
# # Zybooks
#
# * \$39.95, mandatory, lots of interactive exercises and training materials.
#     * Go to https://learn.zybooks.com
#     * Use your **SCHOOL EMAIL** to create a Zybooks account
#     * enter zyBook code: UCSCCSE20PatenFall2025
#     * If you don't have the funds to purchase immediately, see: https://support.zybooks.com/hc/en-us/articles/360007439574-Does-zyBooks-offer-temporary-subscriptions
#
#     * Reading assignments: your first reading assignment is there now!
#         * reading assignments involve reading and participation challenges
#         * readings are due on the following Monday at 11:59pm
#         * there will be a reading assignment for every lecture
#
#     * ~~Programming assignments: your first programming assignment is there now!~~
#         * ~~"micro assignments", one per week, released on Mondays~~
#         * ~~due on following Monday at 11:59pm~~

# %% [markdown]
# # Discord
# * https://discord.gg/bDtyhkPPCG
# * TAs and instructors will be on this Discord.
# * Don't post answers here
# * Please switch your name on the channel to your actual name. TAs and instructors will not answer questions unless you identify yourself.
# * Please don't make an unofficial discord - it definitely encourages cheating.
# * **Any cheating is going to get punished in this class.**
#     * We use software to compare submissions for homework and will spot similarities
#     * This includes similarities to answers posted on the web or those generated by AI (e.g. chatGPT)
#     * We have previously written up students for cheating - that's an automatic fail and a report to the school

# %% [markdown]
# # Grading / Homework
#
# * Lecture Challenges - 10%:
#   * A canvas quiz will be opened during each lecture whose answers depend upon challenge questions presented during the lecture. You have until 11:59 pm on the day before the next lecture to complete the quiz. (This is to encourage regular attendance!)
#
# * Zybooks Readings - 15%:
#   * There is one reading to complete per class
#   * Each reading is worth an equal amount
#   * Readings for the previous week are due on Monday at 11:59pm.
#   * All readings are available now - you are free to read ahead if you like
#
# * ~~Zybooks Assignments - 25%:~~
#   * ~~One per week, will be released weekly on Tuesday.~~
#   * ~~Due on following Monday at 11:59pm.~~
#   * ~~Each assignment is worth an equal amount~~
#
# * Notebook Grader Assignments - 25% see: https://notebookgrader.com
#   * NEW THIS YEAR - We're trying this out based on feedback that students found ZyLabs in Zybooks annoying.
#   * System developed by UCSC professor Luca de Alfaro, uses Google Colab (see later)
#   * Also used, in CSE30, I believe, so good to get familar if you're continuing in CS classes
#   * As with Zybooks, sign up with your UCSC email!
#   * One per week, released weekly on a Monday (first one is there now; 9 total, no assignment the last week)
#   * Due on following Monday at 11:59pm.
#   * Each assignment is worth an equal amount.
#
# * Exams:
#   * Midterm - 20%
#     * In class
#   * Final - 30%

# %% [markdown]
# # Late policy
#
# * Strict but fair:
#    * Partial submissions will get credit
#    * For readings and lecture quizzes: 5% reduction each late day, down to minimum of 50%.
#    * For programming assignments:
#       * Get 80% of credit for anything submitted up to two weeks late, 0% if more than two weeks.
#    *    Late grades will not show up in Canvas until several weeks after submission due to lag in importing them.
#    * To request an exception:
#       * For a reading or quiz with a valid reason (e.g. medical or bereavement) mail Kim (kczupil@ucsc.edu).
#       * For a programming assignment with a valid reason mail Konstantinos and Mira (both, please (kkyriaki@ucsc.edu and mmastora@ucsc.edu)
# * **The late policy is to encourage you to keep up with the course - students who fall behind tend to learn poorly**

# %% [markdown]
# # Setting expectations
#   * This class will not teach computer engineering or electronics.
#   * This class will not teach basic/essential CS tools like the shell, editors, version control, but see here:
#       * https://missing.csail.mit.edu/
#   * This class is a first programming class, you'll be bored if you've already learned to program another language.
#   * Programming is everywhere, it is becoming *essential* as a basic skill in many fields. Even if you don't think you want to be a software engineer, it should allow you to use programming as a tool in **your existing and future work**, to tackle bigger problems, as well as automating mundane things.
#   * To use a bad analogy, if programming is painting, this class alone won't make you Picasso, but it will teach you how to redecorate a room and put you on a course towards mastery.

# %% [markdown]
# # Discussion Sections
#
# * Non Mandatory, TA-led
# * Will go through the practice problems set at the end of each lecture (see later!), as well as reviewing material from the lectures / Zybooks readings.
# * The programming assignments are based upon (but not identical to) these problems
# * These problems will be at the level we expect for this class, with a few stretch questions
# * Discussion sections may also review other questions and generally be a smaller environment to ask questions and work on learning.

# %% [markdown]
# # What's a program?
#
# **Class discussion:**
#
# 1. What is a computer program?
# 2. What is like a computer program?

# %% [markdown]
# Notes for discussion "What's a program":
#
# What is a computer program?
#    * Input --> [ Computer Program ] --> Output
#
# What is like a computer program?
#    * Mathematical functions
#       * Domain --> [ function ] --> Range
#       * Mathematical functions do not need to specify how they are calculated
#    * Algorithm: A finite sequence of well-defined instructions, typically used to solve a class of specific problems or to perform a computation
#       * Think of an algorithm as a "code recipe" for performing a specific task
#    * A computer program is often composed of a series of algorithms, and like an algorithm is composed of sequences of machine readable instructions created by writing code. Here that code will be Python.

# %% [markdown]
# # The notes / slides for this class are programming notebooks:
#
#   * All the lecture notes for this class are free on Github: https://github.com/benedictpaten/intro_python
#
#   * Each lecture has notes formatted as a Jupyter (aka IPython) notebook
#
#     * This one is here: https://bit.ly/intro_python_01
#
#     * **Interactive** The notebooks make it easy to poke around with the examples, they are also a great way to do basic exploratory analysis. They allow you to combine text and code in a natural way.
#
#     * **Colaboratory** Jupyter notebooks can be edited and run in your web browser using Google Colaboratory
#          * https://colab.research.google.com
#          * Paste https://github.com/benedictpaten/intro_python into the GitHub tab (Note: do demo)
#
#     * **On your computer**, you can run the notebook using (free) Jupyter software on your computer (https://jupyter.org/).
#
#     * You can only learn programming by doing it, so use these notebooks to practice!

# %% [markdown]
# # Improve These Lectures and Notes - Extra Credit Available
#
# * I will award extra credit equal to 1% of the grade for the class for each improvement contributed to these lecture notes, which are always a work in progress.
#
# * I will accept improvements at my discretion, but will consider typo fixes, improvements to code examples and exposition, and additional content such as examples - basically anything that improves these notes. I reserve the right to ignore tiny changes or changes that I don't think improve the notes!
#
# * To make an improvement, make a pull request (PR) to the GitHub https://github.com/benedictpaten/intro_python (see: https://docs.github.com/en/pull-requests/collaborating-with-pull-requests/proposing-changes-to-your-work-with-pull-requests/about-pull-requests).
#     * Each PR is equal to one improvement.
#     * I will only take one improvement/PR per lecture, per student.
#     * Students will be responsible for resolving merge conflicts in their PRs.
#     * Note, we don't have time to cover GitHub here, so this will be self-directed.

# %% [markdown]
# # The notes / slides and Zybooks:
# * **Not complete** These lecture notes do not cover everything in the Zybooks text book, they are really supposed to be an interactive exploration of some of the key ideas.
# * **Zybooks** Zybooks provides interactive exercises and is more comprehensive than these notebooks, I have tried to align the notebooks with the Zybooks chapters

# %% [markdown]
# # Hello, world
#
# **Okay, let's write our first program...**

# %%
# Hello world program - this is a comment 
# (it's just to make the code readable)

# Go ahead and run this by hitting the run button
print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# # Challenge 1

# %%
# Print the words: My first program
# Out:
# My first program

# %% [markdown]
# # A Bigger Example
#
# **Now let's look at a more general program...**
#
# (Don't worry if this is all a bit cryptic right now, we'll explain all the bits over the course of these lectures.)

# %%
## A basic program

# Inputs - let's ask the user to input two numbers and 
# call them x and y (x and y are called variables)
x = float(input("Please enter a number: "))
y = float(input("Please enter another number: "))

# Doing stuff

z = x + y # Add the inputs together

# Outputs
# Let's print the result
print(f"The sum of your two inputs is: {z}")
# Out:
# Please enter a number: 8
# Please enter another number: 10
# The sum of your two inputs is: 18.0

# %% [markdown]
# # Challenge 2

# %%
# Adapt the above program to print the product (multiple) of x and y. (you can write your code here)

# %% [markdown]
# # Interpreted vs. Compiled Languages
#
# * Python is (basically) an interpreted language:
#   * Interpreted languages are generally read line-by-line and executed line-by-line.
#   * This allows you to use Python interactively (see below)
#   * You can also get the interpreter to use files, which is much better when you want to save your work.
#
# * Other languages, e.g. C, Java, etc. are *compiled*:
#    * The code is read in its entirety before it is executed.
#    * There are speed (optimization) and error checking benefits to this approach (can catch an error at the end of your program before executing any of it).
#    * But, more complex, and generally no interactive execution.

# %% [markdown]
# # Ways to run Python
#
# * Directly from your web browser using an iPython notebooks (like this one!)
# * Interatively via interpreter (LIVE DEMO)
# * Via a dev environment (LIVE Pycharm DEMO)

# %% [markdown]
# # Basic Input and output

# %%
x = input("What's your name? ") # Input can be be used to gather input from a user.
# Later we'll see ways of getting other kinds of input, like reading from files, but for
# now just know that input reads text from the user
# Out:
# What's your name? Benedict

# %%
# We can print the users input
print(f"Your name is {x}") # Print is a way of outputting formatted text to the string. 
# here x acts as a "variable" to represent the text that input gathered
# Out:
# Your name is Benedict

# %% [markdown]
# # Debugging

# %%
## Our first debugging session!

# Warning - most computer programming is debugging!
# IMO, it is the process of taking an idea (represented by your initial code) and refining it
# into a precise, working program

x = 1
y = 2

## Let's try an assert - a check you can put in your code to establish that something
## is the way you think it should be
assert x + y == 4
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In [10], line 12
#       8 y = 2
#      10 ## Let's try an assert - a check you can put in your code to establish that something
#      11 ## is the way you think it should be
# ---> 12 assert x + y == 4
#
# AssertionError:

# %% [markdown]
# # Comments

# %%
# This is a comment

# Code can be hard to read, and yet you 
# often have to edit and maintain code over time.

# Comments let you keep notes in your code.

# Rule of thumb: Good code is often about 50% code and 50% comments

# It is amazing to read code you wrote last year - you
# likely won't remember how it works without comments!

# Because some text editors don't automatically line-wrap it is a good idea to try to keep your comments to less than 80 or so characters by spreading them across multiple lines. 

# Later on, we'll see docstrings, which are another way
# of documenting code.

# %% [markdown]
# # Basic Types

# %%
# What's the "type" of 1?

# For now, just understand that we can use type() 
# to find out the 'type' of any object in Python

type(1)
# Out:
# int

# %%
# Similarly, 5 is an integer (called an 'int')
type(5)
# Out:
# int

# %%
# Okay, so what's the type of a decimal?
type(3.142)
# Out:
# float

# %%
# And the type of 1.0? 
# (there is no room for indecision/ambiguity in a programming language)
type(1.0)
# Out:
# float

# %% [markdown]
# * Under the hood, Python is storing ints using a different format of bits (zeroes and ones), because floating point math (floats) have different representational requirements to integers (ints).
#   * (Note: Brief, incomplete aside on binary representation on board)
# * In general, a type is a formatting of bits to represent the given information.
# * Types impose constraints, e.g. ints are whole numbers only
# * All objects (things) in Python have a type, and when we define our own objects, we'll define our own types.

# %%
# What about text?
type("hello")
# Out:
# str

# %% [markdown]
# # Challenge 3

# %%
# Find out the type of x
x = [ 1, 2, 3 ]

# %% [markdown]
# # AI Help :)

# %% [markdown]
# Artificial intelligence (AI) is getting pretty good at generating text, and that includes code.
#
# In this class you are welcome to use AI assistants to help you understand and learn what you are doing.
#
# Consider the previous example:

# %%
x = 1
y = 2

assert x + y == 4  ## Why is this wrong?

# %% [markdown]
# Pasted into chatGPT:
#
# <img src="https://raw.githubusercontent.com/benedictpaten/intro_python/main/lecture_notebooks/figures/chatGPT.jpg" width=800 height=400 />

# %% [markdown]
# # AI Cheating
#
# If humans are to have a future role in writing code :), it will clearly be a hybrid role in which we use AI to assist us. AI can help spot bugs (like the above), and remove tedium from writing boiler plate stuff. It is also currently good at helping to write documentation and providing assistance when you don't understand. However, a world in which humans blindly use AI to write code they don't understand is a scary proposition!
#
# You are here to learn Python - to understand Python and know what you are doing. If you simply cut-and-paste the problems from this class into ChatGPT it will mostly just solve them for you. Doing this without understanding will not result in you learning Python.
#
# So, you are welcome to use AI as you like during this class to aid your learning. BUT:
#  * The exams constitute 50% of the mark and will be done old fashioned, on paper in class - no devices!
#  * We will look for plagiarism in homework submissions, so copy-and-paste from an AI will likely result in near identical code to other submissions.

# %% [markdown]
# # Homework:
#
# * Go to Canvas and complete the first lecture quiz, which involves completing each challenge problem
# * See "Reading 1" in Zybooks, available now due by 11:59pm on Monday.
# * You can start Assignment 1 in Notebook grader (see Canvas for link).
#
#
# # Reading:
#
# * Chapter 1 : (http://openbookproject.net/thinkcs/python/english3e/way_of_the_program.html)

# %% [markdown]
# # Practice Problems
#
# Some Python challenges to consolidate your knowledge. These problems are similar to the homework and will be reviewed in discussion section. The exams will also pull from these problems, so it is highly recommended that you have a go at them.

# %%
# Challenge 1: Input and Output
# Write a Python program that asks the user to input their name and age (as an number). 
# Then have the program print out a sentence that says "Hello [name], you are [age] years old!"

# Hint: Use the code from a "Bigger Example" above

# %%
# Challenge 2: Simple Math
# Write a Python program that asks the user to input two decimal numbers using the float() function as in the 
# "Bigger Example" above. 
# Have the program print out the sum, difference, product, and quotient (first number divided by the second) 
# of those two numbers.

# %%
# Challenge 3: Data Types
# Write a Python program that creates a variable for each of the following data types: 
# integer, float, string, and boolean. Print out each variable and its data type using the type() function.

my_int = 42
my_float = 3.14
my_string = "Hello, world!" 
my_bool = True

# Hint: e.g. print(my_int, type(my_int))

# %%
# Challenge 4: Debugging
# The following code has a bug. Find and fix the error
# Hint: at this stage you may not understand the code but you should try running it 
# and reading the error message

x = 5
if x = 6:  
    print("x is 6")
else:
    print("x is not 6")

# %%
# Challenge 5: Comments  
# Take the code you wrote for challenge #2 (Simple Math) and add comments
# to each line explaining what the code is doing. Make sure to include a
# comment at the top summarizing the overall purpose of the program.

# This program takes in two numbers from the user and prints out 
# the sum, difference, product and quotient of those numbers.
